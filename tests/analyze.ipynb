# %%
"""Analyze."""
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib notebook


class ReducedSystem:
    """Reduced system only containing box size and averaged energies."""

    def __init__(self, mean_box, mean_en, std_en, err_en, dil, tot):
        """Initialize."""
        self.ener = mean_en
        self.std = std_en
        self.err = err_en
        self.box = mean_box
        self.dil = dil
        self.tot = tot
        self.phi = dil/tot

# %%
# %matplotlib notebook

# %%
path_0 = '../zendehroud/honey_big_highres/16x32_d0_1_a.pkl'
with open(path_0, 'rb') as inputs:
    obj_0 = pickle.load(inputs)

path_5 = '../zendehroud/honey_big_highres/16x32_d5_100_a.pkl'
with open(path_5, 'rb') as inputs:
    obj_5 = pickle.load(inputs)

path_10 = '../zendehroud/honey_big_highres/16x32_d10_100_a.pkl'
with open(path_10, 'rb') as inputs:
    obj_10 = pickle.load(inputs)
   
path_15 = '../zendehroud/honey_big_highres/16x32_d15_100_a.pkl'
with open(path_15, 'rb') as inputs:
    obj_15 = pickle.load(inputs)

path_20 = '../zendehroud/honey_big_highres/16x32_d20_100_a.pkl'
with open(path_20, 'rb') as inputs:
    obj_20 = pickle.load(inputs)

path_50 = '../zendehroud/honey_big_highres/16x32_d50_100_2_a.pkl'
with open(path_50, 'rb') as inputs:
    obj_50 = pickle.load(inputs)

path_100 = '../zendehroud/honey_big_highres/16x32_d100_100_a.pkl'
with open(path_100, 'rb') as inputs:
    obj_100 = pickle.load(inputs)

path_150 = '../zendehroud/honey_big_highres/16x32_d150_100_a.pkl'
with open(path_150, 'rb') as inputs:
    obj_150 = pickle.load(inputs)

# %%
plt.figure()
plt.plot(obj_0.box[:, 1], np.gradient(obj_0.ener, edge_order=2), '.-', label='d0')
plt.plot(obj_5.box[:, 1], np.gradient(obj_5.ener, edge_order=2), '.-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(obj_10.ener, edge_order=2), '.-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(obj_15.ener, edge_order=2), '.-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(obj_20.ener, edge_order=2), '.-', label='d20')
plt.plot(obj_50.box[:, 1], np.gradient(obj_50.ener, edge_order=2), '.-', label='d50')
plt.plot(obj_100.box[:, 1], np.gradient(obj_100.ener, edge_order=2), '.-', label='d100')
plt.plot(obj_150.box[:, 1], np.gradient(obj_150.ener, edge_order=2), '.-', label='d150')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_5.box[:, 1], np.gradient(np.gradient(obj_5.ener, edge_order=2), edge_order=2), '.-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(np.gradient(obj_10.ener, edge_order=2), edge_order=2), '.-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(np.gradient(obj_15.ener, edge_order=2), edge_order=2), '.-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(np.gradient(obj_20.ener, edge_order=2), edge_order=2), '.-', label='d20')
plt.plot(obj_50.box[:, 1], np.gradient(np.gradient(obj_50.ener, edge_order=2), edge_order=2), '.-', label='d50')
plt.plot(obj_100.box[:, 1], np.gradient(np.gradient(obj_100.ener, edge_order=2), edge_order=2), '.-', label='d100')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(obj_5.box[:, 1], np.gradient(np.gradient(np.gradient(obj_5.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(np.gradient(np.gradient(obj_10.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(np.gradient(np.gradient(obj_15.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(np.gradient(np.gradient(obj_20.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d20')
plt.plot(obj_50.box[:, 1], np.gradient(np.gradient(np.gradient(obj_50.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d50')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], obj_0.ener[:-8], '.-', label='no dilution')
plt.plot(obj_5.box[:, 1], obj_5.ener, '.-', label='0.98 % dilution')
plt.plot(obj_10.box[:, 1], obj_10.ener, '.-', label='1.95 % dilution')
plt.plot(obj_15.box[:, 1], obj_15.ener, '.-', label='2.93 % dilution')
plt.plot(obj_20.box[:, 1], obj_20.ener, '.-', label='3.91 % dilution')
plt.plot(obj_50.box[:, 1], obj_50.ener, '.-', label='9.78 % dilution')
plt.plot(obj_100.box[:, 1], obj_100.ener, '.-', label='19.53 % dilution')
plt.plot(obj_150.box[:, 1], obj_150.ener, '.-', label='29.3 % dilution')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.array([5, 10, 15, 20, 50])/512*100
# Out:
# array([0.9765625, 1.953125 , 2.9296875, 3.90625  , 9.765625 ])

# %%
obj_20.err
# Out:
# array([4.43909479e-31, 1.27701956e-13, 1.79625777e-13, 1.72943110e-13,
#        1.87642967e-13, 2.04141209e-13, 2.50703383e-13, 6.38752508e-13,
#        2.11058349e-05, 1.95014374e-04, 4.79270169e-04, 7.88548620e-04,
#        1.11391188e-03, 1.45446260e-03, 1.81003073e-03, 2.18062035e-03,
#        2.56629097e-03])

# %%
f_100 = np.poly1d(np.polyfit(obj_100.box[27:, 1], obj_100.ener[27:], 2))

# %%
plt.figure()
plt.plot(np.linspace(32, 34), f_100(np.linspace(32, 34)))
plt.plot(obj_100.box[:, 1], obj_100.ener, '.-')
plt.show()

# %%
np.polyfit(obj_0.box[:-8, 1], obj_0.ener[:-8], 2)[0] * 2
# Out:
# 0.3950539689721288

# %%
np.polyfit(obj_5.box[8:, 1], obj_5.ener[8:], 2)[0] * 2
# Out:
# 0.3791879052852315

# %%
np.polyfit(obj_10.box[8:, 1], obj_10.ener[8:], 2)[0] * 2
# Out:
# 0.3612554111458703

# %%
np.polyfit(obj_15.box[10:, 1], obj_15.ener[10:], 2)[0] * 2
# Out:
# 0.347168892869951

# %%
np.polyfit(obj_20.box[12:, 1], obj_20.ener[12:], 2)[0] * 2
# Out:
# 0.3330475224228948

# %%
np.polyfit(obj_50.box[26:, 1], obj_50.ener[26:], 2)[0] * 2
# Out:
# 0.2646829739249167

# %%
np.polyfit(obj_100.box[27:, 1], obj_100.ener[27:], 2)[0] * 2
# Out:
# 0.1267584418699315

# %%
np.polyfit(obj_150.box[10:, 1], obj_150.ener[10:], 2)[0] * 2
# Out:
# 0.029323692011588104

# %%
plt.figure()
plt.plot(np.array([0, 5, 10, 15, 20, 50, 100, 150])/512*100,
         np.array([0.395, 0.379, 0.361, 0.347, 0.333, 0.265, 0.127, 0.029])/0.395,
         's-', color='k')
plt.ylim(0, 1.1)
plt.xlim(-5, 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
