# %%
"""Analyze."""
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib notebook


class ReducedSystem:
    """Reduced system only containing box size and averaged energies."""

    def __init__(self, mean_box, mean_en, std_en, err_en, dil, tot):
        """Initialize."""
        self.ener = mean_en
        self.std = std_en
        self.err = err_en
        self.box = mean_box
        self.dil = dil
        self.tot = tot
        self.phi = dil/tot

# %%
# %matplotlib notebook

# %%
path_0 = '/net/storage/zendehroud/honey_big_highres/16x32_d35_100_a.pkl'
with open(path_0, 'rb') as inputs:
    obj = pickle.load(inputs)

# %%
plt.figure()
X = obj.box[:, 1]
Y = obj.ener
plt.plot(X, Y, '.-')
dX = obj.box[1, 1] - obj.box[0, 1]
dY = np.gradient(obj.ener, dX, edge_order=2)
plt.plot(X, dY, '.-')
ddY = np.gradient(dY, dX, edge_order=2)
plt.plot(X, ddY, '.-')
print(ddY)
dddY = np.gradient(ddY, dX, edge_order=2)
plt.plot(X, dddY, '.-')
print(dddY)
ddddY = np.gradient(dddY, dX, edge_order=2)
plt.plot(X, ddddY, '.-')
print(ddddY)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# [-1.69733135e-11 -9.11472943e-12 -1.79253542e-12  2.20892472e-12
#   5.92511090e-12  4.33185990e-04  2.23899741e-02  1.07788723e-01
#   2.23488694e-01  2.86252484e-01  3.00801447e-01  3.07808195e-01
#   3.14520263e-01  3.21023010e-01  3.27220720e-01  3.33051759e-01
#   3.38509532e-01  3.43607317e-01  3.48387646e-01  3.52907858e-01
#   3.57199872e-01  3.61276117e-01  3.65146001e-01  3.68822574e-01
#   3.72321382e-01  3.75660315e-01  3.78850452e-01  3.81893470e-01
#   3.84793556e-01  3.87563059e-01  3.90215381e-01  3.92149826e-01
#   3.93422057e-01]
# [2.70892635e-11 2.53012967e-11 1.88727569e-11 1.28627439e-11
#  7.21976647e-04 3.73166236e-02 1.78925895e-01 3.35164534e-01
#  2.97439603e-01 1.28854588e-01 3.59261841e-02 2.28646929e-02
#  2.20246915e-02 2.11674282e-02 2.00479152e-02 1.88146859e-02
#  1.75925976e-02 1.64635235e-02 1.55009002e-02 1.46870436e-02
#  1.39470990e-02 1.32435488e-02 1.25774288e-02 1.19589681e-02
# ...

# %%
fit = np.poly1d(np.polyfit(obj_0.box[:-8, 1], np.gradient(obj_0.ener[:-8], obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), 2))
plt.figure()
plt.plot(obj_0.box[:-8, 1], np.gradient(obj_0.ener[:-8], obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), '.', color='k')
plt.plot(np.linspace(24, 28), grad_0(np.linspace(24, 28)), color='r')
plt.show()
