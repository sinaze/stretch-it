# %%
"""Analyze."""
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib notebook


class ReducedSystem:
    """Reduced system only containing box size and averaged energies."""

    def __init__(self, mean_box, mean_en, std_en, err_en, dil, tot):
        """Initialize."""
        self.ener = mean_en
        self.std = std_en
        self.err = err_en
        self.box = mean_box
        self.dil = dil
        self.tot = tot
        self.phi = dil/tot

# %%
# %matplotlib notebook

# %%
path_0 = '/net/storage/zendehroud/honey_big_highres/10x20_d0_100_a.pkl'
with open(path_0, 'rb') as inputs:
    obj_0 = pickle.load(inputs)

path_5 = '/net/storage/zendehroud/honey_big_highres/10x20_d5_100_2_a.pkl'
with open(path_5, 'rb') as inputs:
    obj_5 = pickle.load(inputs)

path_10 = '/net/storage/zendehroud/honey_big_highres/10x20_d10_100_a.pkl'
with open(path_10, 'rb') as inputs:
    obj_10 = pickle.load(inputs)

path_15 = '/net/storage/zendehroud/honey_big_highres/10x20_d15_100_a.pkl'
with open(path_15, 'rb') as inputs:
    obj_15 = pickle.load(inputs)

path_20 = '/net/storage/zendehroud/honey_big_highres/10x20_d20_100_a.pkl'
with open(path_20, 'rb') as inputs:
    obj_20 = pickle.load(inputs)
    
path_25 = '/net/storage/zendehroud/honey_big_highres/10x20_d25_100_a.pkl'
with open(path_25, 'rb') as inputs:
    obj_25 = pickle.load(inputs)

path_30 = '/net/storage/zendehroud/honey_big_highres/10x20_d30_100_a.pkl'
with open(path_30, 'rb') as inputs:
    obj_30 = pickle.load(inputs)
    
path_35 = '/net/storage/zendehroud/honey_big_highres/10x20_d35_100_a.pkl'
with open(path_35, 'rb') as inputs:
    obj_35 = pickle.load(inputs)

path_40 = '/net/storage/zendehroud/honey_big_highres/10x20_d40_100_a.pkl'
with open(path_40, 'rb') as inputs:
    obj_40 = pickle.load(inputs)

path_45 = '/net/storage/zendehroud/honey_big_highres/10x20_d45_100_a.pkl'
with open(path_45, 'rb') as inputs:
    obj_45 = pickle.load(inputs)

path_50 = '/net/storage/zendehroud/honey_big_highres/10x20_d50_100_a.pkl'
with open(path_50, 'rb') as inputs:
    obj_50 = pickle.load(inputs)

path_55 = '/net/storage/zendehroud/honey_big_highres/10x20_d55_100_a.pkl'
with open(path_55, 'rb') as inputs:
    obj_55 = pickle.load(inputs)

# %%
obj_0.box[:, 1], obj_0.ener[:]
# Out:
# (array([24.  , 24.15, 24.3 , 24.45, 24.6 , 24.75, 24.9 , 25.05, 25.2 ,
#         25.35, 25.5 , 25.65, 25.8 , 25.95, 26.1 , 26.25, 26.4 , 26.55,
#         26.7 , 26.85, 27.  , 27.15, 27.3 , 27.45, 27.6 , 27.75, 27.9 ,
#         28.05, 28.2 , 28.35, 28.5 , 28.65, 28.8 ]),
#  array([2.67374543e-28, 3.77325598e-03, 1.51846207e-02, 3.43683601e-02,
#         6.14547089e-02, 9.65700388e-02, 1.39837018e-01, 1.91374764e-01,
#         2.51298986e-01, 3.19722122e-01, 3.96753469e-01, 4.82499306e-01,
#         5.77063013e-01, 6.80545179e-01, 7.93043712e-01, 9.14653938e-01,
#         1.04546870e+00, 1.18557843e+00, 1.33507129e+00, 1.49403319e+00,
#         1.66254790e+00, 1.84069713e+00, 2.02856059e+00, 2.22621607e+00,
#         2.43373950e+00, 2.65120500e+00, 3.00956346e+00, 3.22611523e+00,
#         3.45482778e+00, 3.69571596e+00, 3.94879458e+00, 4.21407838e+00,
#         4.49158204e+00]))

# %%
plt.figure()
plt.plot(obj_0.box[:, 1], np.gradient(obj_0.ener, obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2)[:], '-', label='d0')
plt.plot(obj_5.box[:, 1], np.gradient(obj_5.ener, obj_5.box[1, 1]-obj_5.box[0, 1], edge_order=2), '-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(obj_10.ener, obj_10.box[1, 1]-obj_10.box[0, 1], edge_order=2), '-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(obj_15.ener, obj_15.box[1, 1]-obj_15.box[0, 1], edge_order=2), '-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(obj_20.ener, obj_20.box[1, 1]-obj_20.box[0, 1], edge_order=2), '-', label='d20')
plt.plot(obj_25.box[:0, 1], np.gradient(obj_25.ener, obj_25.box[1, 1]-obj_25.box[0, 1], edge_order=2)[:0], '-', label='d25')
plt.plot(obj_30.box[:, 1], np.gradient(obj_30.ener, obj_30.box[1, 1]-obj_30.box[0, 1], edge_order=2), '-', label='d30')
plt.plot(obj_35.box[:, 1], np.gradient(obj_35.ener, obj_35.box[1, 1]-obj_35.box[0, 1], edge_order=2), '-', label='d35')
plt.plot(obj_40.box[:, 1], np.gradient(obj_40.ener, obj_40.box[1, 1]-obj_40.box[0, 1], edge_order=2), '-', label='d40')
plt.plot(obj_45.box[:, 1], np.gradient(obj_45.ener, obj_45.box[1, 1]-obj_45.box[0, 1], edge_order=2)[:], '-', label='d45')
plt.plot(obj_50.box[:, 1], np.gradient(obj_50.ener, obj_50.box[1, 1]-obj_50.box[0, 1], edge_order=2)[:], '-', label='d50')
plt.plot(obj_55.box[:, 1], np.gradient(obj_55.ener, obj_55.box[1, 1]-obj_55.box[0, 1], edge_order=2)[:], '-', label='d55')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:-25, 1], np.gradient(obj_0.ener, obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2)[:-25], '.-', label='no dilution')
plt.plot(obj_5.box[:-7, 1], np.gradient(obj_5.ener, obj_5.box[1, 1]-obj_5.box[0, 1], edge_order=2)[:-7], '.-', label='0.98 % dilution')
plt.plot(obj_10.box[:-5, 1], np.gradient(obj_10.ener, obj_10.box[1, 1]-obj_10.box[0, 1], edge_order=2)[:-5], '.-', label='1.95 % dilution')
plt.plot(obj_15.box[:-2, 1], np.gradient(obj_15.ener, obj_15.box[1, 1]-obj_15.box[0, 1], edge_order=2)[:-2], '.-', label='2.93 % dilution')
plt.plot(obj_20.box[:, 1], np.gradient(obj_20.ener, obj_20.box[1, 1]-obj_20.box[0, 1], edge_order=2), '.-', label='3.91 % dilution')
plt.plot(obj_35.box[:-20, 1], np.gradient(obj_35.ener, obj_35.box[1, 1]-obj_35.box[0, 1], edge_order=2)[:-20], '.-', label='6.84 % dilution')
plt.plot(obj_50.box[:, 1], np.gradient(obj_50.ener, obj_50.box[1, 1]-obj_50.box[0, 1], edge_order=2), '.-', label='9.77 % dilution')
plt.plot(obj_75.box[:-10, 1], np.gradient(obj_75.ener, obj_75.box[1, 1]-obj_75.box[0, 1], edge_order=2)[:-10], '.-', label='14.65 % dilution')
plt.plot(obj_100.box[:, 1], np.gradient(obj_100.ener, obj_100.box[1, 1]-obj_100.box[0, 1], edge_order=2), '.-', label='19.53 % dilution')
plt.plot(obj_125.box[:-9, 1], np.gradient(obj_125.ener, obj_125.box[1, 1]-obj_125.box[0, 1], edge_order=2)[:-9], '.-', label='24.41 % dilution')
plt.plot(obj_150.box[:-4, 1], np.gradient(obj_150.ener, obj_150.box[1, 1]-obj_150.box[0, 1], edge_order=2)[:-4], '.-', label='29.3 % dilution')
plt.legend()
plt.title('Stress-Strain diagram')
plt.xlabel('$L_y$')
plt.ylabel('$U^\prime (L_y)$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:-25, 1], np.gradient(obj_0.ener, obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2)[:-25], '-', label='no dilution')
plt.plot(obj_5.box[:-7, 1], np.gradient(obj_5.ener, obj_5.box[1, 1]-obj_5.box[0, 1], edge_order=2)[:-7], '-', label='0.98 % dilution')
plt.plot(obj_10.box[:-5, 1], np.gradient(obj_10.ener, obj_10.box[1, 1]-obj_10.box[0, 1], edge_order=2)[:-5], '-', label='1.95 % dilution')
plt.plot(obj_15.box[:-2, 1], np.gradient(obj_15.ener, obj_15.box[1, 1]-obj_15.box[0, 1], edge_order=2)[:-2], '-', label='2.93 % dilution')
plt.plot(obj_20.box[:, 1], np.gradient(obj_20.ener, obj_20.box[1, 1]-obj_20.box[0, 1], edge_order=2), '-', label='3.91 % dilution')
plt.plot(obj_35.box[:-20, 1], np.gradient(obj_35.ener, obj_35.box[1, 1]-obj_35.box[0, 1], edge_order=2)[:-20], '-', label='6.84 % dilution')
plt.plot(obj_50.box[:, 1], np.gradient(obj_50.ener, obj_50.box[1, 1]-obj_50.box[0, 1], edge_order=2), '-', label='9.77 % dilution')
plt.plot(obj_75.box[:-10, 1], np.gradient(obj_75.ener, obj_75.box[1, 1]-obj_75.box[0, 1], edge_order=2)[:-10], '-', label='14.65 % dilution')
plt.plot(obj_100.box[:, 1], np.gradient(obj_100.ener, obj_100.box[1, 1]-obj_100.box[0, 1], edge_order=2), '-', label='19.53 % dilution')
plt.plot(obj_125.box[:-9, 1], np.gradient(obj_125.ener, obj_125.box[1, 1]-obj_125.box[0, 1], edge_order=2)[:-9], '-', label='24.41 % dilution')
plt.plot(obj_150.box[:-4, 1], np.gradient(obj_150.ener, obj_150.box[1, 1]-obj_150.box[0, 1], edge_order=2)[:-4], '-', label='29.3 % dilution')
plt.legend()
plt.title('Stress-Strain diagram')
plt.xlabel('$L_y$')
plt.ylabel('$U^\prime (L_y)$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:, 1], np.gradient(np.gradient(obj_0.ener[:], obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), '-', label='d0')
plt.plot(obj_5.box[:, 1], np.gradient(np.gradient(obj_5.ener, obj_5.box[1, 1]-obj_5.box[0, 1], edge_order=2), obj_5.box[1, 1]-obj_5.box[0, 1], edge_order=2), '-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(np.gradient(obj_10.ener, obj_10.box[1, 1]-obj_10.box[0, 1], edge_order=2), obj_10.box[1, 1]-obj_10.box[0, 1], edge_order=2), '-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(np.gradient(obj_15.ener, obj_15.box[1, 1]-obj_15.box[0, 1], edge_order=2), obj_15.box[1, 1]-obj_15.box[0, 1], edge_order=2), '-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(np.gradient(obj_20.ener, obj_20.box[1, 1]-obj_20.box[0, 1], edge_order=2), obj_20.box[1, 1]-obj_20.box[0, 1], edge_order=2), '-', label='d20')
plt.plot(obj_25.box[:, 1], np.gradient(np.gradient(obj_25.ener, obj_25.box[1, 1]-obj_25.box[0, 1], edge_order=2), obj_25.box[1, 1]-obj_25.box[0, 1], edge_order=2), '-', label='d25')
plt.plot(obj_30.box[:, 1], np.gradient(np.gradient(obj_30.ener, obj_30.box[1, 1]-obj_30.box[0, 1], edge_order=2), obj_30.box[1, 1]-obj_30.box[0, 1], edge_order=2), '-', label='d30')
plt.plot(obj_35.box[:, 1], np.gradient(np.gradient(obj_35.ener, obj_35.box[1, 1]-obj_35.box[0, 1], edge_order=2), obj_35.box[1, 1]-obj_35.box[0, 1], edge_order=2), '-', label='d35')
plt.plot(obj_40.box[:, 1], np.gradient(np.gradient(obj_40.ener, obj_40.box[1, 1]-obj_40.box[0, 1], edge_order=2), obj_40.box[1, 1]-obj_40.box[0, 1], edge_order=2), '-', label='d40')
plt.plot(obj_45.box[:, 1], np.gradient(np.gradient(obj_45.ener, obj_45.box[1, 1]-obj_45.box[0, 1], edge_order=2), obj_45.box[1, 1]-obj_45.box[0, 1], edge_order=2), '-', label='d45')
plt.plot(obj_50.box[:, 1], np.gradient(np.gradient(obj_50.ener, obj_50.box[1, 1]-obj_50.box[0, 1], edge_order=2), obj_50.box[1, 1]-obj_50.box[0, 1], edge_order=2), '-', label='d50')
plt.plot(obj_55.box[:, 1], np.gradient(np.gradient(obj_55.ener, obj_55.box[1, 1]-obj_55.box[0, 1], edge_order=2), obj_55.box[1, 1]-obj_55.box[0, 1], edge_order=2), '-', label='d55')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
grad_150 = np.poly1d(np.polyfit(obj_150.box[-3:, 1], np.gradient(obj_150.ener, obj_150.box[1, 1]-obj_150.box[0, 1], edge_order=2)[-3:], 1))
plt.figure()
plt.plot(obj_150.box[:, 1], np.gradient(obj_150.ener, obj_150.box[1, 1]-obj_150.box[0, 1], edge_order=2)[:], '.', color='k')
plt.plot(np.linspace(35, 63), grad_150(np.linspace(35, 63)), color='r')
plt.plot(np.linspace(23, 50), np.linspace(23, 50)*0, color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
grad_0 = np.poly1d(np.polyfit(obj_0.box[:-8, 1], np.gradient(obj_0.ener[:-8], obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), 2))
plt.figure()
plt.plot(obj_0.box[:-8, 1], np.gradient(obj_0.ener[:-8], obj_0.box[1, 1]-obj_0.box[0, 1], edge_order=2), '.', color='k')
plt.plot(np.linspace(24, 28), grad_0(np.linspace(24, 28)), color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_5.box[:, 1], np.gradient(np.gradient(obj_5.ener, edge_order=2), edge_order=2), '.-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(np.gradient(obj_10.ener, edge_order=2), edge_order=2), '.-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(np.gradient(obj_15.ener, edge_order=2), edge_order=2), '.-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(np.gradient(obj_20.ener, edge_order=2), edge_order=2), '.-', label='d20')
plt.plot(obj_50.box[:, 1], np.gradient(np.gradient(obj_50.ener, edge_order=2), edge_order=2), '.-', label='d50')
plt.plot(obj_75.box[:, 1], np.gradient(np.gradient(obj_75.ener, edge_order=2), edge_order=2), '.-', label='d75')
plt.plot(obj_100.box[:, 1], np.gradient(np.gradient(obj_100.ener, edge_order=2), edge_order=2), '.-', label='d100')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_5.box[:, 1], np.gradient(np.gradient(np.gradient(obj_5.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d5')
plt.plot(obj_10.box[:, 1], np.gradient(np.gradient(np.gradient(obj_10.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d10')
plt.plot(obj_15.box[:, 1], np.gradient(np.gradient(np.gradient(obj_15.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d15')
plt.plot(obj_20.box[:, 1], np.gradient(np.gradient(np.gradient(obj_20.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d20')
plt.plot(obj_50.box[:, 1], np.gradient(np.gradient(np.gradient(obj_50.ener, edge_order=2), edge_order=2), edge_order=2), '.-', label='d50')
plt.legend()
plt.show()

# %%
plt.figure()
plt.errorbar(obj_0.box[:-8, 1], obj_0.ener[:-8], yerr=obj_0.err[:-8], fmt='-', label='no dilution')
plt.errorbar(obj_5.box[:, 1], obj_5.ener, yerr=obj_5.err, fmt='-', label='0.98 % dilution')
plt.errorbar(obj_10.box[:, 1], obj_10.ener, yerr=obj_10.err, fmt='-', label='1.95 % dilution')
plt.errorbar(obj_15.box[:, 1], obj_15.ener, yerr=obj_15.err, fmt='-', label='2.93 % dilution')
plt.errorbar(obj_20.box[:, 1], obj_20.ener, yerr=obj_20.err, fmt='-', label='3.91 % dilution')
plt.errorbar(obj_35.box[:, 1], obj_35.ener, yerr=obj_35.err, fmt='.-', label='6.84 % dilution')
plt.errorbar(obj_50.box[:, 1], obj_50.ener, yerr=obj_50.err, fmt='-', label='9.78 % dilution')
plt.errorbar(obj_75.box[:, 1], obj_75.ener, yerr=obj_75.err, fmt='-', label='14.65 % dilution')
plt.errorbar(obj_100.box[:, 1], obj_100.ener, yerr=obj_100.err, fmt='-', label='19.53 % dilution')
plt.errorbar(obj_125.box[:, 1], obj_125.ener, yerr=obj_125.err, fmt='.-', label='24.41 % dilution')
plt.errorbar(obj_150.box[:-4, 1], obj_150.ener[:-4], yerr=obj_150.err[:-4], fmt='.-', label='29.3 % dilution')
plt.legend()
plt.title('Energy')
plt.xlabel('$y$')
plt.ylabel('$U(y)$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.array([5, 10, 15, 20, 50])/512*100
# Out:
# array([0.9765625, 1.953125 , 2.9296875, 3.90625  , 9.765625 ])

# %%
obj_100.err[27:]
# Out:
# array([0.01178764, 0.01487813, 0.01826773, 0.02194762, 0.02591388,
#        0.03015892])

# %%
p, V = np.polyfit(obj_150.box[7:, 1], obj_150.ener[7:], 2, w=1/(obj_150.err[7:]*10), cov=True)

print("x_1: {} +/- {}".format(p[0], np.sqrt(V[0][0])))
print("x_2: {} +/- {}".format(p[1], np.sqrt(V[1][1])))
print("x_3: {} +/- {}".format(p[2], np.sqrt(V[2][2])))
# Out:
# x_1: 0.013367083121677545 +/- 0.00021109283209870574
# x_2: -0.99972769772897 +/- 0.019892678348610287
# x_3: 18.879335284352237 +/- 0.46369483396631966

# %%
p, V = np.polyfit(obj_0a.box[:-8, 1], obj_0a.ener[:-8], 2, cov=True)

print("x_1: {} +/- {}".format(p[0], np.sqrt(V[0][0])))
print("x_2: {} +/- {}".format(p[1], np.sqrt(V[1][1])))
print("x_3: {} +/- {}".format(p[2], np.sqrt(V[2][2])))
# Out:
# x_1: 0.19752698448607794 +/- 0.00104450045818603
# x_2: -9.52199252348905 +/- 0.053905650649134565
# x_3: 114.7628407927323 +/- 0.6945272371390602

# %%
p, V = np.polyfit(obj_0a.box[:10, 1], obj_0a.ener[:10], 2, cov=True)

print("x_1: {} +/- {}".format(p[0], np.sqrt(V[0][0])))
print("x_2: {} +/- {}".format(p[1], np.sqrt(V[1][1])))
print("x_3: {} +/- {}".format(p[2], np.sqrt(V[2][2])))
# Out:
# x_1: 0.17966375495302667 +/- 0.000984423611311613
# x_2: -8.630339590534161 +/- 0.04858274143812636
# x_3: 103.6423498876636 +/- 0.5992600370317331

# %%
[obj_0a[0][i].ener for i in range(10)]
# Out:
# [2.673745430633467e-28,
#  1.465415679267227e-05,
#  5.863948233922655e-05,
#  0.00013199020679853204,
#  0.00023474049724279977,
#  0.00036692445176896406,
#  0.0005285761027735215,
#  0.0007197294165068411,
#  0.000940418293253497,
#  0.0011906765675104775]

# %%
plt.figure()
plt.plot([obj_0a[0][i].box[1] for i in range(64)], [obj_0a[0][i].ener for i in range(64)], '.-', label='no dilution')
plt.legend()
plt.title('Energy')
plt.xlabel('$y$')
plt.ylabel('$U(y)$')
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
f_0 = np.poly1d(np.polyfit(obj_0.box[:, 1], obj_0.ener[:], 2))
plt.figure()
plt.plot(np.linspace(15, 17), f_0(np.linspace(15, 17)), color='r')
plt.errorbar(obj_0.box[:, 1], obj_0.ener[:], yerr=obj_0.err[:], fmt='.', color='k')
plt.plot(obj_0.box[:, 1], np.gradient(obj_0.ener, edge_order=2)[:]*20, '-', color='purple', alpha=0.5)
#plt.axvline(x=obj_0.box[3, 1], color='grey', alpha=0.5)
plt.title('d0')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.polyfit(obj_0_ext.box[:, 1], np.gradient(obj_0_ext.ener, edge_order=2), 1)
# Out:
# array([ 0.00334303, -0.08027486])

# %%
np.gradient(np.gradient(obj_0_ext.ener, edge_order=2), edge_order=2)
# Out:
# array([2.93226112e-05, 2.93397263e-05, 2.93653831e-05, 2.93995487e-05,
#        2.94336477e-05, 2.94676799e-05, 2.95016462e-05, 2.95355466e-05,
#        2.95693811e-05, 2.96031500e-05, 2.96368535e-05, 2.96704918e-05,
#        2.97040650e-05, 2.97375733e-05, 2.97710168e-05, 2.98043958e-05,
#        2.98377105e-05, 2.98709609e-05, 2.99041473e-05, 2.99372699e-05,
#        2.99703287e-05, 3.00033241e-05, 3.00362561e-05, 3.00691250e-05,
#        3.01019309e-05, 3.01346739e-05, 3.01673543e-05, 3.01999722e-05,
#        3.02325278e-05, 3.02650212e-05, 3.02974526e-05, 3.03298222e-05,
#        3.03621302e-05, 3.03943767e-05, 3.04265618e-05, 3.04586858e-05,
#        3.04907487e-05, 3.05227509e-05, 3.05546924e-05, 3.05865733e-05,
#        3.06183939e-05, 3.06501543e-05, 3.06818547e-05, 3.07134953e-05,
#        3.07450761e-05, 3.07765973e-05, 3.08080592e-05, 3.08394618e-05,
#        3.08708054e-05, 3.09020900e-05, 3.09333158e-05, 3.09644831e-05,
# ...

# %%
plt.figure()
plt.plot(obj_0_ext.box[:, 1], np.gradient(np.gradient(obj_0_ext.ener, edge_order=1)))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_0 = np.poly1d(np.polyfit([obj_0a[0][i].box[1] for i in range(5)], [obj_0a[0][i].ener for i in range(5)], 2))
plt.figure()
plt.plot(np.linspace(24, 24.6), f_0(np.linspace(24, 24.6)), color='r')
plt.plot([obj_0a[0][i].box[1] for i in range(64)], [obj_0a[0][i].ener for i in range(64)], '.', color='k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-66f967c735fd> in <module>()
# ----> 1 f_0 = np.poly1d(np.polyfit([obj_0a[0][i].box[1] for i in range(5)], [obj_0a[0][i].ener for i in range(5)], 2))
#       2 plt.figure()
#       3 plt.plot(np.linspace(24, 24.6), f_0(np.linspace(24, 24.6)), color='r')
#       4 plt.plot([obj_0a[0][i].box[1] for i in range(64)], [obj_0a[0][i].ener for i in range(64)], '.', color='k')
#       5 plt.show()
#
# <ipython-input-7-66f967c735fd> in <listcomp>(.0)
# ----> 1 f_0 = np.poly1d(np.polyfit([obj_0a[0][i].box[1] for i in range(5)], [obj_0a[0][i].ener for i in range(5)], 2))
#       2 plt.figure()
#       3 plt.plot(np.linspace(24, 24.6), f_0(np.linspace(24, 24.6)), color='r')
#       4 plt.plot([obj_0a[0][i].box[1] for i in range(64)], [obj_0a[0][i].ener for i in range(64)], '.', color='k')
#       5 plt.show()
#
# ...

# %%
f_5 = np.poly1d(np.polyfit(obj_5.box[12:, 1], obj_5.ener[12:], 2, w=1/(obj_5.err[12:]*10)))
plt.figure()
plt.plot(np.linspace(15, 16.5), f_5(np.linspace(15, 16.5)), color='r')
plt.errorbar(obj_5.box[12:, 1], obj_5.ener[12:], yerr=obj_5.err[12:], fmt='.', color='k')
plt.errorbar(obj_5.box[:12, 1], obj_5.ener[:12], yerr=obj_5.err[:12], fmt='.', color='grey')
plt.plot(obj_5.box[:, 1], np.gradient(obj_5.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_5.box[12, 1], color='grey', alpha=0.5)
plt.title('d5')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_10 = np.poly1d(np.polyfit(obj_10.box[12:, 1], obj_10.ener[12:], 2, w=1/(obj_10.err[12:]*10)))
plt.figure()
plt.plot(np.linspace(15, 18), f_10(np.linspace(15, 18)), color='r')
plt.errorbar(obj_10.box[12:, 1], obj_10.ener[12:], yerr=obj_10.err[12:], fmt='.', color='k')
plt.errorbar(obj_10.box[:12, 1], obj_10.ener[:12], yerr=obj_10.err[:12], fmt='.', color='grey')
plt.plot(obj_10.box[:, 1], np.gradient(obj_10.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_10.box[12, 1], color='grey', alpha=0.12)
plt.title('d10')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_15 = np.poly1d(np.polyfit(obj_15.box[9:, 1], obj_15.ener[9:], 2, w=1/(obj_15.err[9:]*10)))
plt.figure()
plt.plot(np.linspace(15, 22), f_15(np.linspace(15, 22)), color='r')
plt.errorbar(obj_15.box[9:, 1], obj_15.ener[9:], yerr=obj_15.err[9:], fmt='.', color='k')
plt.errorbar(obj_15.box[:9, 1], obj_15.ener[:9], yerr=obj_15.err[:9], fmt='.', color='grey')
plt.plot(obj_15.box[:, 1], np.gradient(obj_15.ener, edge_order=2)[:]*20, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_15.box[9, 1], color='grey', alpha=0.5)
plt.title('d15')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_20 = np.poly1d(np.polyfit(obj_20.box[12:, 1], obj_20.ener[12:], 2, w=1/(obj_20.err[12:]*10)))
plt.figure()
plt.plot(np.linspace(15, 21), f_20(np.linspace(15, 21)), color='r')
plt.errorbar(obj_20.box[12:, 1], obj_20.ener[12:], yerr=obj_20.err[12:], fmt='.', color='k')
plt.errorbar(obj_20.box[:12, 1], obj_20.ener[:12], yerr=obj_20.err[:12], fmt='.', color='grey')
plt.plot(obj_20.box[:, 1], np.gradient(obj_20.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_20.box[12, 1], color='grey', alpha=0.5)
plt.title('d20')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_25 = np.poly1d(np.polyfit(obj_25.box[15:, 1], obj_25.ener[15:], 2, w=1/(obj_25.err[15:]*10)))
plt.figure()
plt.plot(np.linspace(15, 21), f_25(np.linspace(15, 21)), color='r')
plt.errorbar(obj_25.box[15:, 1], obj_25.ener[15:], yerr=obj_25.err[15:], fmt='.', color='k')
plt.errorbar(obj_25.box[:15, 1], obj_25.ener[:15], yerr=obj_25.err[:15], fmt='.', color='grey')
plt.plot(obj_25.box[:, 1], np.gradient(obj_25.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_25.box[15, 1], color='grey', alpha=0.5)
plt.title('d25')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_30 = np.poly1d(np.polyfit(obj_30.box[11:, 1], obj_30.ener[11:], 2, w=1/(obj_30.err[11:]*10)))
plt.figure()
plt.plot(np.linspace(15, 28), f_30(np.linspace(15, 28)), color='r')
plt.errorbar(obj_30.box[11:, 1], obj_30.ener[11:], yerr=obj_30.err[11:], fmt='.', color='k')
plt.errorbar(obj_30.box[:11, 1], obj_30.ener[:11], yerr=obj_30.err[:11], fmt='.', color='grey')
plt.plot(obj_30.box[:, 1], np.gradient(obj_30.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_30.box[11, 1], color='grey', alpha=0.5)
plt.title('d30')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_35 = np.poly1d(np.polyfit(obj_35.box[11:, 1], obj_35.ener[11:], 2, w=1/(obj_35.err[11:]*10)))
plt.figure()
plt.plot(np.linspace(15, 28), f_35(np.linspace(15, 28)), color='r')
plt.errorbar(obj_35.box[11:, 1], obj_35.ener[11:], yerr=obj_35.err[11:], fmt='.', color='k')
plt.errorbar(obj_35.box[:11, 1], obj_35.ener[:11], yerr=obj_35.err[:11], fmt='.', color='grey')
plt.plot(obj_35.box[:, 1], np.gradient(obj_35.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_35.box[11, 1], color='grey', alpha=0.5)
plt.title('d35')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_40 = np.poly1d(np.polyfit(obj_40.box[13:, 1], obj_40.ener[13:], 2, w=1/(obj_40.err[13:]*10)))
plt.figure()
plt.plot(np.linspace(15, 28), f_40(np.linspace(15, 28)), color='r')
plt.errorbar(obj_40.box[13:, 1], obj_40.ener[13:], yerr=obj_40.err[13:], fmt='.', color='k')
plt.errorbar(obj_40.box[:13, 1], obj_40.ener[:13], yerr=obj_40.err[:13], fmt='.', color='grey')
plt.plot(obj_40.box[:, 1], np.gradient(obj_40.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_40.box[13, 1], color='grey', alpha=0.5)
plt.title('d40')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_45 = np.poly1d(np.polyfit(obj_45.box[14:, 1], obj_45.ener[14:], 2, w=1/(obj_45.err[14:]*10)))
plt.figure()
plt.plot(np.linspace(15, 28), f_45(np.linspace(15, 28)), color='r')
plt.errorbar(obj_45.box[14:, 1], obj_45.ener[14:], yerr=obj_45.err[14:], fmt='.', color='k')
plt.errorbar(obj_45.box[:14, 1], obj_45.ener[:14], yerr=obj_45.err[:14], fmt='.', color='grey')
plt.plot(obj_45.box[:, 1], np.gradient(obj_45.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_45.box[14, 1], color='grey', alpha=0.14)
plt.title('d45')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_50 = np.poly1d(np.polyfit(obj_50.box[11:, 1], obj_50.ener[11:], 2, w=1/(obj_50.err[11:]*10)))
plt.figure()
plt.plot(np.linspace(15, 40), f_50(np.linspace(15, 40)), color='r')
plt.errorbar(obj_50.box[11:, 1], obj_50.ener[11:], yerr=obj_50.err[11:], fmt='.', color='k')
plt.errorbar(obj_50.box[:11, 1], obj_50.ener[:11], yerr=obj_50.err[:11], fmt='.', color='grey')
plt.plot(obj_50.box[:, 1], np.gradient(obj_50.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_50.box[11, 1], color='grey', alpha=0.5)
plt.title('d50')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_55 = np.poly1d(np.polyfit(obj_55.box[6:, 1], obj_55.ener[6:], 2, w=1/(obj_55.err[6:]*10)))
plt.figure()
plt.plot(np.linspace(15, 65), f_55(np.linspace(15, 65)), color='r')
plt.errorbar(obj_55.box[6:, 1], obj_55.ener[6:], yerr=obj_55.err[6:], fmt='.', color='k')
plt.errorbar(obj_55.box[:6, 1], obj_55.ener[:6], yerr=obj_55.err[:6], fmt='.', color='grey')
plt.plot(obj_55.box[:, 1], np.gradient(obj_55.ener, edge_order=2)[:]*10, '-', color='purple', alpha=0.5)
plt.axvline(x=obj_55.box[6, 1], color='grey', alpha=0.5)
plt.title('d55')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_0 = np.poly1d(np.polyfit(obj_0.box[:-8, 1], obj_0.ener[:-8], 2))
plt.figure()
plt.plot(np.linspace(24, 30), f_0(np.linspace(24, 30)), color='r')
plt.plot(obj_0.box[:, 1], obj_0.ener[:], '.', color='k')
#plt.errorbar(obj_0.box[:, 1], obj_150.ener[:], yerr=obj_150.err[:], fmt='.', color='grey')
#plt.plot(obj_150.box[:, 1], np.gradient(obj_150.ener, edge_order=2)[:], '.-', color='purple')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p, V = np.polyfit(obj_0.box[:, 1], obj_0.ener[:], 2, cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.3770627451245086 +/- 0.0012989438387726957

# %%
p, V = np.polyfit(obj_5.box[12:, 1], obj_5.ener[12:], 2, w=1/(obj_5.err[12:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.3423690147264386 +/- 0.001017080596295695

# %%
p, V = np.polyfit(obj_10.box[12:, 1], obj_10.ener[12:], 2, w=1/(obj_10.err[12:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.3327908073250688 +/- 0.001571116081971807

# %%
p, V = np.polyfit(obj_15.box[9:, 1], obj_15.ener[9:], 2, w=1/(obj_15.err[9:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.3249365217075054 +/- 0.00231130615891722

# %%
p, V = np.polyfit(obj_20.box[12:, 1], obj_20.ener[12:], 2, w=1/(obj_20.err[12:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.28620723584666125 +/- 0.0021069162390330294

# %%
p, V = np.polyfit(obj_25.box[15:, 1], obj_25.ener[15:], 2, w=1/(obj_25.err[15:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.23583011675573565 +/- 0.002223576999801802

# %%
p, V = np.polyfit(obj_30.box[11:, 1], obj_30.ener[11:], 2, w=1/(obj_30.err[11:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.23444335902919955 +/- 0.0014328272504563768

# %%
p, V = np.polyfit(obj_35.box[11:, 1], obj_35.ener[11:], 2, w=1/(obj_35.err[11:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.18593816038101774 +/- 0.0016849069917746692

# %%
p, V = np.polyfit(obj_40.box[13:, 1], obj_40.ener[13:], 2, w=1/(obj_40.err[13:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.13971662982132105 +/- 0.0013686944424100718

# %%
p, V = np.polyfit(obj_45.box[14:, 1], obj_45.ener[14:], 2, w=1/(obj_45.err[14:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.1037510719881512 +/- 0.0011092539349318027

# %%
p, V = np.polyfit(obj_50.box[11:, 1], obj_50.ener[11:], 2, w=1/(obj_50.err[11:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.08801463732995432 +/- 0.0006310742726919612

# %%
p, V = np.polyfit(obj_55.box[6:, 1], obj_55.ener[6:], 2, w=1/(obj_55.err[6:]*10), cov=True)
print("curvature: {} +/- {}".format(2*p[0], 2*np.sqrt(V[0][0])))
# Out:
# curvature: 0.06527393761271139 +/- 0.0004124789895900864

# %%
plt.figure()
plt.errorbar(np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])/200*100,
         np.array([0.377, 0.342, 0.333, 0.325, 0.286, 0.236, 0.230, 0.186, 0.140, 0.104, 0.088, 0.065])/0.377,
         yerr=np.array([0.001, 0.001, 0.002, 0.002, 0.002, 0.003, 0.002, 0.002, 0.001, 0.001, 0.001, 0.0004]) ,
         fmt='s-', color='k', label='theory (10x20)')
#plt.errorbar(np.array([0, 5, 10, 15, 20, 35, 50, 75, 100, 125, 150])/512*100,
#         np.array([0.395, 0.360, 0.348, 0.336, 0.323, 0.311, 0.256, 0.210, 0.123, 0.08, 0.028])/0.395,
#         yerr=np.array([0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.0003]) ,
#         fmt='s-', color='b', label='theory (16x32)')
#plt.errorbar(np.array([0, 5, 10, 20, 80, 120, 160])/800*100,
#         np.array([0.377, 0.345, 0.337, 0.342, 0.291, 0.189, 0.116])/0.377,
#         yerr=np.array([0.001, 0.001, 0.001, 0.002, 0.003, 0.003, 0.002]) ,
#         fmt='s-', color='purple', label='theory (20x40)')
plt.plot([0, 1, 5, 10, 25, 50],
         [523/523, 390/523, 362/523, 299/523, 198/523, 119/523],
         's-.', color='r', label='mixing (exp)')
plt.plot([0, 0.1, 0.5, 1, 2.5, 5, 10, 25, 50, 100],
         [1, 376.44/412.523, 362.8/412.523, 296.55/412.523, 267.66/412.523,
          229.55/412.523, 239.43/412.523, 172.8/412.523, 151.8/412.523, 51.76/412.523],
         's-.', color='g', label='titration (exp)')
plt.ylim(0, 1.1)
plt.xlim(-5, 105)
plt.title('Rescaled Modulus')
plt.ylabel('$\Delta \kappa$')
plt.xlabel('dilution fraction (%), net-4 concentration (%)')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
#plt.errorbar(np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])/200*100,
#         np.array([0.377, 0.342, 0.333, 0.325, 0.286, 0.236, 0.230, 0.186, 0.140, 0.104, 0.088, 0.065])/0.377,
#         yerr=np.array([0.001, 0.001, 0.002, 0.002, 0.002, 0.003, 0.002, 0.002, 0.001, 0.001, 0.001, 0.0004]) ,
#         fmt='s-', color='k', label='theory (10x20)')
plt.errorbar(np.array([0, 5, 10, 15, 20, 35, 50, 75, 100, 125, 150])/512*100,
         np.array([0.395, 0.360, 0.348, 0.336, 0.323, 0.311, 0.256, 0.210, 0.123, 0.08, 0.028])/0.395,
         yerr=np.array([0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.0003]) ,
         fmt='s-', color='k', label='theory (16x32)')
#plt.errorbar(np.array([0, 5, 10, 20, 80, 120, 160])/800*100,
#         np.array([0.377, 0.345, 0.337, 0.342, 0.291, 0.189, 0.116])/0.377,
#         yerr=np.array([0.001, 0.001, 0.001, 0.002, 0.003, 0.003, 0.002]) ,
#         fmt='s-', color='purple', label='theory (20x40)')
plt.plot([0, 1, 5, 10, 25, 50],
         [523/523, 390/523, 362/523, 299/523, 198/523, 119/523],
         's-.', color='r', label='mixing (exp)')
plt.plot([0, 0.1, 0.5, 1, 2.5, 5, 10, 25, 50, 100],
         [1, 376.44/412.523, 362.8/412.523, 296.55/412.523, 267.66/412.523,
          229.55/412.523, 239.43/412.523, 172.8/412.523, 151.8/412.523, 51.76/412.523],
         's-.', color='g', label='titration (exp)')
plt.ylim(0, 1.1)
plt.xlim(-5, 105)
plt.title('Rescaled Modulus')
plt.ylabel('$\Delta \kappa$')
plt.xlabel('dilution fraction (%), net-4 concentration (%)')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
#plt.errorbar(np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])/200*100,
#         np.array([0.377, 0.342, 0.333, 0.325, 0.286, 0.236, 0.230, 0.186, 0.140, 0.104, 0.088, 0.065])/0.377,
#         yerr=np.array([0.001, 0.001, 0.002, 0.002, 0.002, 0.003, 0.002, 0.002, 0.001, 0.001, 0.001, 0.0004]) ,
#         fmt='s-', color='k', label='theory (10x20)')
#plt.errorbar(np.array([0, 5, 10, 15, 20, 35, 50, 75, 100, 125, 150])/512*100,
#         np.array([0.395, 0.360, 0.348, 0.336, 0.323, 0.311, 0.256, 0.210, 0.123, 0.08, 0.028])/0.395,
#         yerr=np.array([0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.0003]) ,
#         fmt='s-', color='k', label='theory (16x32)')
plt.errorbar(np.array([0, 5, 10, 20, 80, 120, 160])/800*100,
         np.array([0.377, 0.345, 0.337, 0.342, 0.291, 0.189, 0.116])/0.377,
         yerr=np.array([0.001, 0.001, 0.001, 0.002, 0.003, 0.003, 0.002]) ,
         fmt='s-', color='k', label='theory (20x40)')
plt.plot([0, 1, 5, 10, 25, 50],
         [523/523, 390/523, 362/523, 299/523, 198/523, 119/523],
         's-.', color='r', label='mixing (exp)')
plt.plot([0, 0.1, 0.5, 1, 2.5, 5, 10, 25, 50, 100],
         [1, 376.44/412.523, 362.8/412.523, 296.55/412.523, 267.66/412.523,
          229.55/412.523, 239.43/412.523, 172.8/412.523, 151.8/412.523, 51.76/412.523],
         's-.', color='g', label='titration (exp)')
plt.ylim(0, 1.1)
plt.xlim(-5, 105)
plt.title('Rescaled Modulus')
plt.ylabel('$\Delta \kappa$')
plt.xlabel('dilution fraction (%), net-4 concentration (%)')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(dpi=300)
plt.errorbar(np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])/200*100,
         np.array([0.377, 0.342, 0.333, 0.325, 0.286, 0.236, 0.230, 0.186, 0.140, 0.104, 0.088, 0.065])/0.377,
         yerr=np.array([0.001, 0.001, 0.002, 0.002, 0.002, 0.003, 0.002, 0.002, 0.001, 0.001, 0.001, 0.0004]) ,
         fmt='s-', label='10x20 lattice, 100 run average')
plt.errorbar(np.array([0, 5, 10, 15, 20, 35, 50, 75, 100, 125, 150])/512*100,
         np.array([0.377, 0.360, 0.348, 0.336, 0.323, 0.311, 0.256, 0.210, 0.123, 0.08, 0.028])/0.377,
         yerr=np.array([0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.0003]) ,
         fmt='s-', label='16x32 lattice, 100 run average')
plt.errorbar(np.array([0, 5, 10, 20, 80, 120, 160])/800*100,
         np.array([0.377, 0.345, 0.337, 0.335, 0.291, 0.189, 0.116])/0.377,
         yerr=np.array([0.001, 0.001, 0.001, 0.002, 0.003, 0.003, 0.002]) ,
         fmt='s-', label='20x40 lattice, 10 run average')
#plt.plot([0, 1, 5, 10, 25, 50],
#         [523/523, 390/523, 362/523, 299/523, 198/523, 119/523],
#         's-.', color='r', label='mixing (exp)')
#plt.plot([0, 0.1, 0.5, 1, 2.5, 5, 10, 25, 50, 100],
#         [1, 376.44/412.523, 362.8/412.523, 296.55/412.523, 267.66/412.523,
#          229.55/412.523, 239.43/412.523, 172.8/412.523, 151.8/412.523, 51.76/412.523],
#         's-.', color='g', label='titration (exp)')
plt.ylim(0, 1.1)
plt.xlim(-1, 31)
plt.title('Rescaled Modulus')
plt.ylabel('$\Delta \kappa$')
plt.xlabel('dilution fraction (%)')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999">

# %%
plt.figure()
plt.errorbar(np.array([0, 5, 10, 15, 20, 50, 75, 100, 150])/512*100,
         np.array([0.365, 0.360, 0.348, 0.336, 0.323, 0.256, 0.210, 0.123, 0.028])/0.365,
         yerr=np.array([0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.0003]) ,
         fmt='s-', color='k', label='theory')
plt.plot([0, 1, 5, 10, 25, 50],
         [523/523, 390/523, 362/523, 299/523, 198/523, 119/523],
         's-.', color='r', label='mixing (exp)')
plt.plot([0, 0.1, 0.5, 1, 2.5, 5, 10, 25, 50, 100],
         [1, 376.44/412.523, 362.8/412.523, 296.55/412.523, 267.66/412.523,
          229.55/412.523, 239.43/412.523, 172.8/412.523, 151.8/412.523, 51.76/412.523],
         's-.', color='g', label='titration (exp)')
plt.ylim(0, 1.1)
plt.xlim(-5, 105)
plt.title('Rescaled Modulus')
plt.ylabel('$\Delta \kappa$')
plt.xlabel('dilution fraction (%), net-4 concentration (%)')
plt.legend()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
path_1 = '/net/storage/zendehroud/honey_big_highres/16x32_d1_100_a.pkl'
with open(path_1, 'rb') as inputs:
    obj_1 = pickle.load(inputs)

path_2 = '/net/storage/zendehroud/honey_big_highres/16x32_d2_100_a.pkl'
with open(path_2, 'rb') as inputs:
    obj_2 = pickle.load(inputs)

path_3 = '/net/storage/zendehroud/honey_big_highres/16x32_d3_100_a.pkl'
with open(path_3, 'rb') as inputs:
    obj_3 = pickle.load(inputs)

path_4 = '/net/storage/zendehroud/honey_big_highres/16x32_d4_100_a.pkl'
with open(path_4, 'rb') as inputs:
    obj_4 = pickle.load(inputs)

# %%
obj_1.ener
# Out:
# array([2.66483747e-28, 1.30079287e-03, 9.52991206e-03, 2.54527973e-02,
#        4.92000448e-02, 8.08983326e-02, 1.20670586e-01, 1.68636134e-01,
#        2.24910858e-01, 2.89607331e-01, 3.62834953e-01, 4.44700077e-01,
#        5.35306127e-01, 6.34753714e-01, 7.43140747e-01, 8.60562529e-01,
#        9.87111864e-01, 1.12287914e+00, 1.26795244e+00, 1.42241758e+00,
#        1.58635825e+00, 1.75985605e+00, 1.94299058e+00, 2.13583949e+00,
#        2.33847857e+00, 2.55098183e+00, 2.99051124e+00, 3.20584540e+00,
#        3.43329157e+00, 3.67286455e+00, 3.92457908e+00, 4.18844982e+00,
#        4.46449140e+00])

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], obj_0.ener[:-8], '-', label='no dilution')
plt.plot(obj_1.box[:-8, 1], obj_1.ener[:-8], '-', label='0.98 % dilution')
plt.plot(obj_2.box[:, 1], obj_2.ener, '-', label='1.95 % dilution')
plt.plot(obj_3.box[:, 1], obj_3.ener, '-', label='2.93 % dilution')
plt.plot(obj_4.box[:, 1], obj_4.ener, '-', label='3.91 % dilution')
plt.plot(obj_5.box[:, 1], obj_5.ener, '-', label='3.91 % dilution')
plt.legend()
plt.title('Energy')
plt.xlabel('$y$')
plt.ylabel('$U(y)$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], np.gradient(obj_0.ener, edge_order=2)[:-8], '.', label='d0')
plt.plot(obj_1.box[:-8, 1], np.gradient(obj_1.ener, edge_order=2)[:-8], '.', label='d1')
plt.plot(obj_2.box[:, 1], np.gradient(obj_2.ener, edge_order=2), '.', label='d2')
plt.plot(obj_3.box[:, 1], np.gradient(obj_3.ener, edge_order=2), '.', label='d3')
plt.plot(obj_4.box[:, 1], np.gradient(obj_4.ener, edge_order=2), '.', label='d4')
plt.plot(obj_5.box[:, 1], np.gradient(obj_5.ener, edge_order=2)[:], '.', label='d5')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f_1 = np.poly1d(np.polyfit(obj_1.box[1:5, 1], obj_1.ener[1:5], 2, w=1/(obj_1.err[1:5]*10)))
plt.figure()
plt.plot(np.linspace(24, 28), f_1(np.linspace(24, 28)), color='r')
plt.errorbar(obj_1.box[0, 1], obj_1.ener[0], yerr=obj_1.err[0], fmt='.', color='grey')
plt.errorbar(obj_1.box[1:5, 1], obj_1.ener[1:5], yerr=obj_1.err[1:5], fmt='.', color='k')
plt.errorbar(obj_1.box[5:-8, 1], obj_1.ener[5:-8], yerr=obj_1.err[5:-8], fmt='.', color='grey')
#plt.plot(obj_1.box[:-8, 1], np.gradient(obj_1.ener, edge_order=2)[:-8], '.-', color='purple')
plt.title('d1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], np.gradient(obj_0.ener, edge_order=2)[:-8], '.-', label='d0')
plt.plot(obj_1.box[:-8, 1], np.gradient(obj_1.ener, edge_order=1)[:-8], '.-', label='d1')
plt.plot(obj_2.box[:, 1], np.gradient(obj_2.ener, edge_order=1), '.-', label='d2')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
path_1_ext = '/net/storage/zendehroud/honey_big_highres/16x32_d1_1_extra2.pkl'
with open(path_1_ext, 'rb') as inputs:
    obj_1_ext = pickle.load(inputs)

# %%
[obj_1_ext[0][i].ener for i in range(9)]
# Out:
# [2.6487853785542083e-28,
#  4.511782092718562e-12,
#  2.9472858653673884e-05,
#  0.0004299729398737695,
#  0.0013007932140323883,
#  0.0026440762922642844,
#  0.004461951598787409,
#  0.006756531692126732,
#  0.009529912009969414]

# %%
[obj_1_ext[0][i].box[1] for i in range(9)]
# Out:
# [24.0,
#  24.037499999999998,
#  24.075000000000003,
#  24.112499999999997,
#  24.150000000000002,
#  24.1875,
#  24.224999999999998,
#  24.262500000000003,
#  24.299999999999997]

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], np.gradient(obj_0.ener, edge_order=2)[:-8], '.-', label='d0')
plt.plot([obj_1_ext[0][i].box[1] for i in range(9)], np.gradient([obj_1_ext[0][i].ener for i in range(9)], edge_order=2), '.-', label='d1')
plt.plot(obj_1.box[:-8, 1], np.gradient(obj_1.ener, edge_order=1)[:-8], '.-', label='d1a')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(obj_0.box[:-8, 1], obj_0.ener[:-8], '.-', label='d0')
plt.plot([obj_1_ext[0][i].box[1] for i in range(9)], [obj_1_ext[0][i].ener for i in range(9)], '.-', label='d1')
plt.plot(obj_1.box[:-8, 1], obj_1.ener[:-8], '.-', label='d1a')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
